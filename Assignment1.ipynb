# %%
import os
import json
import pandas as pd

# %%
data_path = r"C:\Users\Rafallex\Documents\Uppsala\Semester 3\Mathematical modelling of football\open-data-master\data"

# %%
with open(os.path.join(data_path, "competitions.json")) as f:
    competitions = json.load(f)

# Convert to DataFrame for easy filtering
competitions_df = pd.DataFrame(competitions)
competitions_df.head()
